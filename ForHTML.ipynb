# %%
    import pandas as pd
    file_path = r"Dataset/glass.data"

    glass = pd.read_csv(file_path, header=None)

    glass.columns = ["Id", "RI", "Na", "Mg", "Al", "Si", "K", "Ca", "Ba", "Fe", "Type"]
    
    glass.set_index("Id", inplace=True)

# %%
glass.head()
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# Id
# 1   1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 2   1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 3   1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 4   1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 5   1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
glass.RI.min(), glass.RI.max()
# Out:
# (1.51115, 1.53393)

# %%
glass.Na.min(), glass.Na.max()
# Out:
# (10.73, 17.38)

# %%
glass.Mg.min(), glass.Mg.max()
# Out:
# (0.0, 4.49)

# %%
glass.Al.min(), glass.Al.max()
# Out:
# (0.29, 3.5)

# %%
glass.Si.min(), glass.Si.max()
# Out:
# (69.81, 75.41)

# %%
glass.K.min(), glass.K.max()
# Out:
# (0.0, 6.21)

# %%
glass.Ca.min(), glass.Ca.max()
# Out:
# (5.43, 16.19)

# %%
glass.Ba.min(), glass.Ba.max()
# Out:
# (0.0, 3.15)

# %%
glass.Fe.min(), glass.Fe.max()
# Out:
# (0.0, 0.51)
